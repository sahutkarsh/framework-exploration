# %%
import numpy as np
import pandas as pd

# %%
columns = ['Incident Type', 'Primary Cause', 'Cause Class', 'Cause Type', 'Working Condition', 'Machine Condition',
           'SOP Requirement', 'SOP Availability', 'SOP Adequacy', 'SOP Compliance']

# %%
data_dict = {}

# %%
data_dict['Incident Type'] = ['Injury', 'Near Miss', 'Property Damage']
data_dict['Primary Cause'] = ['Dashing/Collision', 'Derailment', 'Energy Isolation', 'Road Incident', 'Slip/Trip/Fall',
                              'Process Incidents', 'Occupational Illness', 'Equipment Machinery Damage', 'Material Handling',
                              'Lifting Tool Tackles', 'Structural Integrity', 'Working at Height']
data_dict['Cause Class'] = ['Behaviour', 'Process']
data_dict['Cause Type'] = ['Unsafe Act', 'Unsafe Act & Unsafe Condition', 'Unsafe Act by Other', 'Unsafe Condition']
data_dict['Working Condition'] = ['Group Working', 'Single Working', 'Not a Working Place']
data_dict['Machine Condition'] = ['M/C Idle', 'M/C Working', 'Not Applicable']
data_dict['SOP Requirement'] = ['SOP Required', 'SOP Not Required', 'Not Known']
data_dict['SOP Availability'] = ['SOP Available', 'SOP Not Available', 'Not Known']
data_dict['SOP Adequacy'] = ['SOP Adequate', 'SOP Not Adequate', 'Not Known']
data_dict['SOP Compliance'] = ['SOP Followed', 'SOP Not Followed', 'Not Known']

# %%
data_df = pd.DataFrame()
size = 1000

# %%
for column in columns:
    n_class = len(data_dict[column])
    data_df[column] = np.random.randint(n_class, size=size)
    data_df[column] = data_df[column].map(lambda item: data_dict[column][item])

# %%
data_df
# Out:
#        Incident Type               Primary Cause Cause Class  \
# 0          Near Miss           Process Incidents     Process
# 1    Property Damage                  Derailment   Behaviour
# 2             Injury        Lifting Tool Tackles   Behaviour
# 3             Injury            Energy Isolation     Process
# 4             Injury  Equipment Machinery Damage     Process
# 5          Near Miss                  Derailment     Process
# 6          Near Miss        Lifting Tool Tackles   Behaviour
# 7             Injury              Slip/Trip/Fall     Process
# 8             Injury        Structural Integrity   Behaviour
# 9    Property Damage            Energy Isolation     Process
# 10   Property Damage                  Derailment     Process
# 11         Near Miss               Road Incident     Process
# 12         Near Miss        Lifting Tool Tackles   Behaviour
# 13   Property Damage        Lifting Tool Tackles   Behaviour
# 14   Property Damage  Equipment Machinery Damage   Behaviour
# 15   Property Damage               Road Incident     Process
# 16         Near Miss           Dashing/Collision   Behaviour
# 17   Property Damage        Occupational Illness   Behaviour
# 18            Injury           Material Handling   Behaviour
# 19         Near Miss        Lifting Tool Tackles   Behaviour
# 20            Injury            Energy Isolation     Process
# 21            Injury           Dashing/Collision   Behaviour
# 22            Injury              Slip/Trip/Fall   Behaviour
# 23            Injury           Working at Height   Behaviour
# 24         Near Miss           Dashing/Collision     Process
# 25            Injury  Equipment Machinery Damage     Process
# 26         Near Miss  Equipment Machinery Damage   Behaviour
# 27         Near Miss           Working at Height     Process
# 28         Near Miss        Structural Integrity   Behaviour
# 29   Property Damage            Energy Isolation     Process
# ..               ...                         ...         ...
# 970  Property Damage  Equipment Machinery Damage     Process
# 971        Near Miss           Dashing/Collision   Behaviour
# 972           Injury           Process Incidents     Process
# 973  Property Damage  Equipment Machinery Damage   Behaviour
# 974  Property Damage        Lifting Tool Tackles   Behaviour
# 975           Injury           Working at Height     Process
# 976  Property Damage              Slip/Trip/Fall     Process
# 977        Near Miss           Working at Height   Behaviour
# 978        Near Miss           Dashing/Collision   Behaviour
# 979        Near Miss                  Derailment   Behaviour
# 980           Injury  Equipment Machinery Damage   Behaviour
# 981           Injury              Slip/Trip/Fall     Process
# 982        Near Miss                  Derailment   Behaviour
# 983           Injury        Structural Integrity     Process
# 984           Injury  Equipment Machinery Damage     Process
# 985           Injury        Structural Integrity     Process
# 986  Property Damage           Process Incidents     Process
# 987  Property Damage  Equipment Machinery Damage   Behaviour
# 988  Property Damage                  Derailment     Process
# 989           Injury        Occupational Illness     Process
# 990  Property Damage              Slip/Trip/Fall     Process
# 991  Property Damage            Energy Isolation     Process
# 992           Injury        Structural Integrity   Behaviour
# 993        Near Miss  Equipment Machinery Damage     Process
# 994           Injury  Equipment Machinery Damage     Process
# 995           Injury           Working at Height     Process
# 996        Near Miss           Working at Height     Process
# 997           Injury  Equipment Machinery Damage     Process
# 998  Property Damage            Energy Isolation   Behaviour
# 999  Property Damage           Dashing/Collision     Process
#
#                         Cause Type    Working Condition Machine Condition  \
# 0                 Unsafe Condition        Group Working    Not Applicable
# 1                 Unsafe Condition  Not a Working Place    Not Applicable
# 2                       Unsafe Act  Not a Working Place    Not Applicable
# 3              Unsafe Act by Other  Not a Working Place    Not Applicable
# 4              Unsafe Act by Other  Not a Working Place       M/C Working
# 5                 Unsafe Condition       Single Working    Not Applicable
# 6                 Unsafe Condition       Single Working    Not Applicable
# 7    Unsafe Act & Unsafe Condition       Single Working    Not Applicable
# 8              Unsafe Act by Other  Not a Working Place       M/C Working
# 9                       Unsafe Act        Group Working          M/C Idle
# 10   Unsafe Act & Unsafe Condition  Not a Working Place    Not Applicable
# 11                Unsafe Condition  Not a Working Place          M/C Idle
# 12             Unsafe Act by Other        Group Working          M/C Idle
# 13   Unsafe Act & Unsafe Condition  Not a Working Place       M/C Working
# 14             Unsafe Act by Other  Not a Working Place    Not Applicable
# 15                      Unsafe Act       Single Working       M/C Working
# 16             Unsafe Act by Other        Group Working          M/C Idle
# 17                Unsafe Condition        Group Working    Not Applicable
# 18   Unsafe Act & Unsafe Condition        Group Working       M/C Working
# 19                Unsafe Condition  Not a Working Place    Not Applicable
# 20   Unsafe Act & Unsafe Condition        Group Working       M/C Working
# 21                Unsafe Condition        Group Working          M/C Idle
# 22   Unsafe Act & Unsafe Condition        Group Working          M/C Idle
# 23   Unsafe Act & Unsafe Condition       Single Working    Not Applicable
# 24                Unsafe Condition       Single Working       M/C Working
# 25                Unsafe Condition       Single Working       M/C Working
# 26             Unsafe Act by Other  Not a Working Place          M/C Idle
# 27             Unsafe Act by Other       Single Working       M/C Working
# 28                      Unsafe Act        Group Working    Not Applicable
# 29                      Unsafe Act        Group Working       M/C Working
# ..                             ...                  ...               ...
# 970  Unsafe Act & Unsafe Condition       Single Working       M/C Working
# 971               Unsafe Condition       Single Working    Not Applicable
# 972                     Unsafe Act        Group Working    Not Applicable
# 973                     Unsafe Act        Group Working          M/C Idle
# 974               Unsafe Condition       Single Working    Not Applicable
# 975               Unsafe Condition        Group Working       M/C Working
# 976            Unsafe Act by Other        Group Working       M/C Working
# 977            Unsafe Act by Other  Not a Working Place       M/C Working
# 978  Unsafe Act & Unsafe Condition  Not a Working Place    Not Applicable
# 979  Unsafe Act & Unsafe Condition  Not a Working Place       M/C Working
# 980  Unsafe Act & Unsafe Condition        Group Working          M/C Idle
# 981                     Unsafe Act       Single Working          M/C Idle
# 982               Unsafe Condition  Not a Working Place          M/C Idle
# 983               Unsafe Condition        Group Working          M/C Idle
# 984            Unsafe Act by Other  Not a Working Place          M/C Idle
# 985                     Unsafe Act       Single Working       M/C Working
# 986  Unsafe Act & Unsafe Condition  Not a Working Place    Not Applicable
# 987  Unsafe Act & Unsafe Condition       Single Working       M/C Working
# 988            Unsafe Act by Other       Single Working          M/C Idle
# 989                     Unsafe Act       Single Working       M/C Working
# 990  Unsafe Act & Unsafe Condition       Single Working       M/C Working
# 991                     Unsafe Act       Single Working          M/C Idle
# 992                     Unsafe Act        Group Working    Not Applicable
# 993               Unsafe Condition        Group Working    Not Applicable
# 994  Unsafe Act & Unsafe Condition  Not a Working Place    Not Applicable
# 995  Unsafe Act & Unsafe Condition        Group Working    Not Applicable
# 996               Unsafe Condition  Not a Working Place       M/C Working
# 997  Unsafe Act & Unsafe Condition       Single Working    Not Applicable
# 998  Unsafe Act & Unsafe Condition  Not a Working Place          M/C Idle
# 999            Unsafe Act by Other        Group Working          M/C Idle
#
#       SOP Requirement   SOP Availability      SOP Adequacy    SOP Compliance
# 0        SOP Required  SOP Not Available         Not Known      SOP Followed
# 1        SOP Required  SOP Not Available  SOP Not Adequate  SOP Not Followed
# 2    SOP Not Required  SOP Not Available  SOP Not Adequate         Not Known
# 3        SOP Required          Not Known  SOP Not Adequate         Not Known
# 4        SOP Required  SOP Not Available         Not Known         Not Known
# 5        SOP Required      SOP Available      SOP Adequate  SOP Not Followed
# 6        SOP Required          Not Known         Not Known      SOP Followed
# 7    SOP Not Required      SOP Available         Not Known      SOP Followed
# 8        SOP Required      SOP Available      SOP Adequate      SOP Followed
# 9        SOP Required      SOP Available      SOP Adequate      SOP Followed
# 10   SOP Not Required  SOP Not Available      SOP Adequate      SOP Followed
# 11   SOP Not Required  SOP Not Available      SOP Adequate         Not Known
# 12          Not Known          Not Known         Not Known         Not Known
# 13   SOP Not Required      SOP Available      SOP Adequate      SOP Followed
# 14          Not Known          Not Known         Not Known         Not Known
# 15          Not Known  SOP Not Available  SOP Not Adequate         Not Known
# 16       SOP Required      SOP Available  SOP Not Adequate  SOP Not Followed
# 17          Not Known          Not Known  SOP Not Adequate         Not Known
# 18          Not Known  SOP Not Available      SOP Adequate      SOP Followed
# 19       SOP Required      SOP Available  SOP Not Adequate         Not Known
# 20   SOP Not Required      SOP Available         Not Known  SOP Not Followed
# 21          Not Known  SOP Not Available         Not Known         Not Known
# 22       SOP Required  SOP Not Available  SOP Not Adequate         Not Known
# 23          Not Known      SOP Available  SOP Not Adequate  SOP Not Followed
# 24   SOP Not Required          Not Known  SOP Not Adequate  SOP Not Followed
# 25          Not Known          Not Known  SOP Not Adequate         Not Known
# 26   SOP Not Required          Not Known      SOP Adequate         Not Known
# 27          Not Known      SOP Available      SOP Adequate      SOP Followed
# 28          Not Known          Not Known      SOP Adequate         Not Known
# 29       SOP Required  SOP Not Available      SOP Adequate      SOP Followed
# ..                ...                ...               ...               ...
# 970  SOP Not Required          Not Known         Not Known      SOP Followed
# 971  SOP Not Required      SOP Available         Not Known      SOP Followed
# 972         Not Known      SOP Available      SOP Adequate         Not Known
# 973         Not Known  SOP Not Available  SOP Not Adequate  SOP Not Followed
# 974      SOP Required          Not Known         Not Known  SOP Not Followed
# 975      SOP Required          Not Known         Not Known  SOP Not Followed
# 976         Not Known      SOP Available      SOP Adequate         Not Known
# 977      SOP Required          Not Known         Not Known  SOP Not Followed
# 978  SOP Not Required  SOP Not Available  SOP Not Adequate  SOP Not Followed
# 979         Not Known          Not Known  SOP Not Adequate      SOP Followed
# 980  SOP Not Required          Not Known         Not Known         Not Known
# 981      SOP Required          Not Known  SOP Not Adequate      SOP Followed
# 982         Not Known      SOP Available      SOP Adequate         Not Known
# 983         Not Known      SOP Available  SOP Not Adequate  SOP Not Followed
# 984  SOP Not Required  SOP Not Available      SOP Adequate         Not Known
# 985  SOP Not Required  SOP Not Available      SOP Adequate      SOP Followed
# 986  SOP Not Required      SOP Available  SOP Not Adequate         Not Known
# 987      SOP Required  SOP Not Available  SOP Not Adequate  SOP Not Followed
# 988      SOP Required          Not Known         Not Known         Not Known
# 989         Not Known  SOP Not Available         Not Known  SOP Not Followed
# 990      SOP Required  SOP Not Available         Not Known  SOP Not Followed
# 991         Not Known      SOP Available      SOP Adequate         Not Known
# 992         Not Known  SOP Not Available      SOP Adequate  SOP Not Followed
# 993      SOP Required          Not Known      SOP Adequate      SOP Followed
# 994      SOP Required      SOP Available  SOP Not Adequate      SOP Followed
# 995      SOP Required          Not Known      SOP Adequate      SOP Followed
# 996         Not Known      SOP Available      SOP Adequate         Not Known
# 997      SOP Required  SOP Not Available         Not Known  SOP Not Followed
# 998         Not Known  SOP Not Available         Not Known         Not Known
# 999  SOP Not Required          Not Known  SOP Not Adequate         Not Known
#
# [1000 rows x 10 columns]

# %%
data_df.to_csv('data.csv', index=False)
